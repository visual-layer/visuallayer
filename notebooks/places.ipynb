# %%
# from torchvision.datasets import Places365

# %%
# train_dataset = Places365('./', split='train-standard', small=True, download=True)

# %%
# valid_dataset = Places365('./', split='val', small=True, download=True)

# %%
from vl_datasets import CleanPlaces365

train_dataset = CleanPlaces365('places365_data', split='train-standard', small=True, download=False, exclude_csv='./places365_images_issue_file_list.csv')
valid_dataset = CleanPlaces365('places365_data', split='val', small=True, download=False, exclude_csv='./places365_images_issue_file_list.csv')
# Out:
# /media/dnth/Active-Projects/vl-datasets/vl_datasets/places365.py:33: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.exclude_df = pd.read_csv(self.exclude_csv, header=0)
# /media/dnth/Active-Projects/vl-datasets/vl_datasets/places365.py:33: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.exclude_df = pd.read_csv(self.exclude_csv, header=0)

# %%
train_dataset.imgs
# Out:
# [('places365_data/data_256_standard/a/airfield/00000001.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000002.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000003.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000004.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000005.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000006.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000007.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000008.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000009.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000010.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000011.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000012.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000013.jpg', 0),
#  ('places365_data/data_256_standard/a/airfield/00000014.jpg', 0),
# ...

# %%
train_dataset.exclude_set
# Out:
# {'train/bathroom/00003621.jpg',
#  'train/grotto/00003239.jpg',
#  'train/discotheque/00000335.jpg',
#  'train/grotto/00002136.jpg',
#  'train/orchestra_pit/00001207.jpg',
#  'train/youth_hostel/00002903.jpg',
#  'train/manufactured_home/00000467.jpg',
#  'train/office_cubicles/00000796.jpg',
#  'train/cabin-outdoor/00000243.jpg',
#  'train/grotto/00004464.jpg',
#  'train/field_road/00002823.jpg',
#  'train/ruin/00004368.jpg',
#  'train/tree_farm/00001731.jpg',
#  'train/wind_farm/00004278.jpg',
#  'train/lighthouse/00000548.jpg',
#  'train/hotel_room/00002465.jpg',
#  'train/canal-urban/00002992.jpg',
#  'train/water_tower/00002317.jpg',
#  'train/parking_garage-indoor/00001722.jpg',
#  'train/desert_road/00001599.jpg',
#  'train/computer_room/00002554.jpg',
#  'train/desert-sand/00000622.jpg',
#  'train/creek/00001126.jpg',
#  'train/reception/00002158.jpg',
#  'train/bathroom/00004659.jpg',
#  'train/alcove/00004075.jpg',
#  'train/airfield/00004532.jpg',
# ...

# %%
valid_dataset.exclude_set

# %%
valid_dataset.imgs
